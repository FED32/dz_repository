# %% [markdown]
# **Задание 1**
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
# - если источник traffic_source равен yandex или google, то в source_type ставится organic
# - для источников paid и email из России - ставим ad
# - для источников paid и email не из России - ставим other
# - все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd

# %%
data = pd.read_csv('visit_log.csv', sep=';')

# %%
# data

# %%
data['source_type'] = data.traffic_source

# %%
data
# Out:
#         timestamp    visit_id                                 url   region  \
# 0      1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1      1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2      1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3      1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4      1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# ...           ...         ...                                 ...      ...
# 18933  1550094288  57e5ba8560  https://host.ru/c2382eb3d6afc8d0f3  Belarus
# 18934  1550094296  6f9389ec1b  https://host.ru/f1eb4601740d627ab0   Russia
# 18935  1550094308  e8cf2eb8e6  https://host.ru/a5dda93e70318570c0  Belarus
# 18936  1550094314  79530b9a67  https://host.ru/6fda01ec57f23abc9e   Russia
# 18937  1550094323  b3b634f824  https://host.ru/39fa884393666d45fc   Russia
#
#           user_id traffic_source source_type
# 0      b1613cc09f         yandex      yandex
# 1      4c3ec14bee         direct      direct
# 2      a8c40697fb         yandex      yandex
# 3      521ac1d6a0         yandex      yandex
# 4      d7323c571c         yandex      yandex
# ...           ...            ...         ...
# 18933  98b19810d0           paid        paid
# 18934  32ebb20c13           paid        paid
# 18935  b85baa8c73         yandex      yandex
# 18936  e154b06121           paid        paid
# 18937  7d27a58fb8          email       email
#
# [18938 rows x 7 columns]

# %%
data.loc[(data.traffic_source == 'yandex') | (data.traffic_source == 'google'), 'source_type'] = 'organic'

# %%
# data

# %%
data.loc[((data.traffic_source == 'paid') | (data.traffic_source == 'email')) & (data.region == 'Russia'), 'source_type'] = 'ad'

# %%
# data.sample(50)

# %%
data.loc[((data.traffic_source == 'paid') | (data.traffic_source == 'email')) & (data.region != 'Russia'), 'source_type'] = 'other'

# %%
data.sample(50)
# Out:
#         timestamp    visit_id                                 url     region  \
# 11113  1550047027  7f895f838b  https://host.ru/da83c74e35e7806fe0     Russia
# 1420   1549989091  9f0380200f  https://host.ru/8880fd00cf23066541    Ukraine
# 18649  1550092645  cd774093b7  https://host.ru/8fe7c39e5c598bbc54    Ukraine
# 14776  1550069026  299babd169  https://host.ru/2fcb223266880ccf57     Russia
# 9520   1550037521  3cf1f38d88  https://host.ru/fd32c3d2de55949865     Russia
# 5611   1550014480  ea4f0e64b9  https://host.ru/a5dda93e70318570c0     Russia
# 7649   1550026488  2760588afe  https://host.ru/ac2d98a5a63e7c6e28    Belarus
# 10110  1550041041  bc0dced4dc  https://host.ru/4adc8a29b212051b04     Russia
# 13175  1550059194  5a9ac5cd67  https://host.ru/6407d4271d7b23cdf5     Russia
# 9319   1550036314  eee1c7b649  https://host.ru/f1eb4601740d627ab0     Russia
# 12839  1550057272  6fd52b916c  https://host.ru/2fcb223266880ccf57    Belarus
# 5794   1550015550  5608ef35ce  https://host.ru/1afc5618562365020a     Russia
# 5907   1550016238  04e3cb6bfe  https://host.ru/8e88d4703848cc0ec4     Russia
# 13200  1550059339  173c45f331  https://host.ru/05e41944dd85a900a6     Russia
# 10255  1550041934  297a9cb299  https://host.ru/4adc8a29b212051b04    Belarus
# 18695  1550092910  18b7a63efa  https://host.ru/f1eb4601740d627ab0     Russia
#
#           user_id traffic_source source_type
# 11113  51255c7ac2         google     organic
# 1420   a16f21d493         google     organic
# 18649  046f871157         direct      direct
# 14776  148c2921e7         direct      direct
# 9520   475582df64          email          ad
# 5611   ff989d7f27          email          ad
# 1381   a36ce80e5d         yandex     organic
# 13219  6e0a9a0b93         direct      direct
# 18753  a7ba539318         yandex     organic
# 4506   aae6e05972          email          ad
# 16351  0fe5788c51         direct      direct
# 9687   67ce930872         yandex     organic
# 16865  60a73b38f6          email       other
# 7525   a38f6a2968          email          ad
# 2730   b14b9eca9f         direct      direct
# 14845  2a156945af         yandex     organic
# 3131   0e6ae2d1b0         direct      direct
# 13073  0cd0d513ce         yandex     organic
# 4300   a495e24a1e         direct      direct
# 13669  e8446b2e30         direct      direct
# 314    9a3012cdf0         direct      direct
# 17449  f4b94913c7         yandex     organic
# 18488  d39a136a15         google     organic
# 1460   3b5780d0e5         google     organic
# 5657   27a5c9db42         direct      direct
# 7541   9f2a625dfe         google     organic
# 10878  7b2c59e016         google     organic
# 2585   0abcb9f008         direct      direct
# 8093   599e8428f2          email       other
# 18229  1bdb8567e5         direct      direct
# 110    019df375b3         direct      direct
# 7008   6055c1f954          email          ad
# 17440  1e1c138ee0         google     organic
# 893    e7099d67f6          email          ad
# 663    78b1749cc7         google     organic
# 13942  fa15e8deeb         direct      direct
# 640    fa13fbadd7         direct      direct
# 17248  037110eba7         direct      direct
# 85     c6a1c8d8df         yandex     organic
# 9295   29998c6320         yandex     organic
# 7649   12c7867132          email       other
# 10110  ac57ae7891         direct      direct
# 13175  3dd2e819ae          email          ad
# 9319   8e8863211f         direct      direct
# 12839  22b4c091d0         direct      direct
# 5794   2f17bd4eac         direct      direct
# 5907   3f6fd9b464          email          ad
# 13200  62c7fa90b9         direct      direct
# 10255  33fd48aad4           paid       other
# 18695  62793a4652         direct      direct

# %% [markdown]
# **Задание 2**
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
# 1. Прочитайте содержимое файла с датафрейм
# 2. Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
# f = open('URLs.txt', 'r')
# urls_1 = f.readlines()
# urls_1

# %%
urls = pd.read_csv('URLs.txt')

# %%
urls
# Out:
#                                                   url
# 0                                             /world/
# 1                                            /latest/
# 2                                       /?updated=top
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [93 rows x 1 columns]

# %%
import re

# %%
pattern = r'/\d{8}-'

# %%
# re.findall(pattern, str(urls.loc[90:90]))

# %%
urls[urls.url.str.contains(pattern)]
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [84 rows x 1 columns]

# %% [markdown]
# Домашнее задание 3
#
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})

# %%
data
# Out:
#                  keyword   shows
# 0    курс гривны к рублю  125076
# 1        доллары в рубли  114173
# 2  100 долларов в рублях   97534
# 3             курс рубля   53546

# %%
# pip install pymystem3

# %%
from pymystem3 import Mystem

# %%
def lemmas_finder(row):
    m = Mystem()
    return ' '.join(m.lemmatize(row['keyword'])).strip('\n')

# %%
data['lemmas'] = data.apply(lemmas_finder, axis=1)

# %%
data
# Out:
#                  keyword   shows                      lemmas
# 0    курс гривны к рублю  125076  курс   гривна   к   рубль
# 1        доллары в рубли  114173         доллар   в   рубль
# 2  100 долларов в рублях   97534   100   доллар   в   рубль
# 3             курс рубля   53546               курс   рубль
