# %% [markdown]
# **Задание 1**
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
# - если источник traffic_source равен yandex или google, то в source_type ставится organic
# - для источников paid и email из России - ставим ad
# - для источников paid и email не из России - ставим other
# - все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd

# %%
data = pd.read_csv('visit_log.csv', sep=';')

# %%
data
# Out:
#         timestamp    visit_id                                 url   region  \
# 0      1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1      1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2      1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3      1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4      1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# ...           ...         ...                                 ...      ...
# 18933  1550094288  57e5ba8560  https://host.ru/c2382eb3d6afc8d0f3  Belarus
# 18934  1550094296  6f9389ec1b  https://host.ru/f1eb4601740d627ab0   Russia
# 18935  1550094308  e8cf2eb8e6  https://host.ru/a5dda93e70318570c0  Belarus
# 18936  1550094314  79530b9a67  https://host.ru/6fda01ec57f23abc9e   Russia
# 18937  1550094323  b3b634f824  https://host.ru/39fa884393666d45fc   Russia
#
#           user_id traffic_source
# 0      b1613cc09f         yandex
# 1      4c3ec14bee         direct
# 2      a8c40697fb         yandex
# 3      521ac1d6a0         yandex
# 4      d7323c571c         yandex
# ...           ...            ...
# 18933  98b19810d0           paid
# 18934  32ebb20c13           paid
# 18935  b85baa8c73         yandex
# 18936  e154b06121           paid
# 18937  7d27a58fb8          email
#
# [18938 rows x 6 columns]

# %%
# data.loc[(data.traffic_source == 'yandex') | (data.traffic_source == 'google')]

# %%
data.loc[(data.traffic_source == 'yandex') | (data.traffic_source == 'google'), 'source_type'] = 'organic'

# %%
data
# Out:
#         timestamp    visit_id                                 url   region  \
# 0      1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1      1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2      1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3      1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4      1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# ...           ...         ...                                 ...      ...
# 18933  1550094288  57e5ba8560  https://host.ru/c2382eb3d6afc8d0f3  Belarus
# 18934  1550094296  6f9389ec1b  https://host.ru/f1eb4601740d627ab0   Russia
# 18935  1550094308  e8cf2eb8e6  https://host.ru/a5dda93e70318570c0  Belarus
# 18936  1550094314  79530b9a67  https://host.ru/6fda01ec57f23abc9e   Russia
# 18937  1550094323  b3b634f824  https://host.ru/39fa884393666d45fc   Russia
#
#           user_id traffic_source source_type
# 0      b1613cc09f         yandex     organic
# 1      4c3ec14bee         direct         NaN
# 2      a8c40697fb         yandex     organic
# 3      521ac1d6a0         yandex     organic
# 4      d7323c571c         yandex     organic
# ...           ...            ...         ...
# 18933  98b19810d0           paid         NaN
# 18934  32ebb20c13           paid         NaN
# 18935  b85baa8c73         yandex     organic
# 18936  e154b06121           paid         NaN
# 18937  7d27a58fb8          email         NaN
#
# [18938 rows x 7 columns]

# %%
data.loc[((data.traffic_source == 'paid') | (data.traffic_source == 'email')) & data.region == 'Russia', 'source_type'] = 'ad'

# %%
data.sample(50)
# Out:
#         timestamp    visit_id                                 url     region  \
# 8925   1550034069  1794d37a64  https://host.ru/6407d4271d7b23cdf5     Russia
# 12893  1550057545  44aed55017  https://host.ru/6fda01ec57f23abc9e     Russia
# 10875  1550045611  151019be1e  https://host.ru/1be58f19f26458f2fe     Russia
# 10938  1550045978  2444566cbe  https://host.ru/2fcb223266880ccf57      China
# 10930  1550045923  8c3fa05198  https://host.ru/8fe7c39e5c598bbc54      India
# 6025   1550016971  7e8adda286  https://host.ru/df646c3676cc259fa0     Russia
# 10567  1550043778  83af86b922  https://host.ru/fd32c3d2de55949865     Russia
#
#           user_id traffic_source source_type source_type_1
# 8925   e791c701d1         google     organic           NaN
# 17717  c8d367cac5         yandex     organic           NaN
# 6203   c42642bea5         direct         NaN           NaN
# 10241  1c2cc9b2e9         direct         NaN           NaN
# 4340   356872921d         google     organic           NaN
# 17955  844049b17e         google     organic           NaN
# 6069   b2ad08a489         direct         NaN           NaN
# 11454  e4b3b31217           paid         NaN           NaN
# 18282  768a1871f3         google     organic           NaN
# 1435   288a2a3c1c         yandex     organic           NaN
# 10643  708f82dec4         google     organic           NaN
# 18048  a0a9ab55b2         google     organic           NaN
# 17102  60c2c9f9b7         yandex     organic           NaN
# 15313  2189666499         yandex     organic           NaN
# 5732   607905f41c         google     organic           NaN
# 8462   6bb54152c9         google     organic           NaN
# 13501  3644f7d7a8          email         NaN           NaN
# 1329   a4a5569c0c          email         NaN           NaN
# 18667  ffeda1a753           paid         NaN           NaN
# 10622  f3d26355c4         direct         NaN           NaN
# 7303   9ff0880556         google     organic           NaN
# 3726   1657437b05         direct         NaN           NaN
# 6155   6472025dc5         google     organic           NaN
# 6797   b445fcce22          email         NaN           NaN
# 3800   ce3086bea3         yandex     organic           NaN
# 13059  afe93dc734          email         NaN           NaN
# 18839  8c8e92b94c         google     organic           NaN
# 10796  0e469717c0          email         NaN           NaN
# 16070  7d46fe89a6         google     organic           NaN
# 17637  a563b5754e          email         NaN           NaN
# 4855   c19ba589ba          email         NaN           NaN
# 945    5c2452950a          email         NaN           NaN
# 8641   c71b4392b2         yandex     organic           NaN
# 16227  b564b7bc81          email         NaN           NaN
# 16267  1cc8955658           paid         NaN           NaN
# 5995   ceb293698c          email         NaN           NaN
# 14310  bd18aa1853          email         NaN           NaN
# 14870  91999aa21e          email         NaN           NaN
# 1915   fb9060bee8         yandex     organic           NaN
# 8080   8ad2102663         direct         NaN           NaN
# 261    e117661e17           paid         NaN           NaN
# 16583  43f3d6640f         yandex     organic           NaN
# 6127   5f94f71f95         direct         NaN           NaN
# 15531  724f502ed8         direct         NaN           NaN
# 12893  99d67b24a4         google     organic           NaN
# 10875  811e5f4ee6         google     organic           NaN
# 10938  9391104cf4         direct         NaN           NaN
# 10930  cb62c135b1          email         NaN           NaN
# 6025   d30a776403         direct         NaN           NaN
# 10567  1d8a3959b8         direct         NaN           NaN

# %% [markdown]
# **Задание 2**
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
# 1. Прочитайте содержимое файла с датафрейм
# 2. Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %% [markdown]
# Домашнее задание 3
#
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})
