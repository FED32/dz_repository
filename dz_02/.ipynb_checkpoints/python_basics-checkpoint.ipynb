# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase > short_phrase
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
byte_vol = 1048576
mbyte_vol = byte_vol / (2**20)
print ('Объем файла равен', mbyte_vol, 'Mb')
# Out:
# Объем файла равен 1.0 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# используем следующий диапазон дат:
# овен 21 марта — 20 апреля
# телец 21 апреля — 21 мая
# близнецы 22 мая — 21 июня
# рак 22 июня — 22 июля
# лев 23 июля — 21 августа
# дева 22 августа — 23 сентября
# весы 24 сентября — 23 октября
# скорпион 24 октября — 22 ноября
# стрелец 23 ноября — 22 декабря
# козерог 23 декабря — 20 января
# водолей 21 января — 19 февраля
# рыбы 20 февраля — 20 марта

month = input('Введите месяц: ')
day = int (input ('Введите число: '))

#print ('Введите месяц:')
#month = input()

#print ('Введите день')
#day = int (input())

#if (month == 'январь') or (month == 'февраль') or (month == 'март') or (month == 'апрель') or (month == 'май')\
#or (month == 'июнь') or (month == 'июль') or (month == 'август') or (month == 'сентябрь') or (month == 'октябрь')\
#or (month == 'ноябрь') or (month == 'декабрь') or (1 <= day <= 31):
#       if ((month == 'январь') and (day > 31)) or\
#          ((month == 'февраль') and (day > 29)) or\
#          ((month == 'март') and (day > 31)) or\
#          ((month == 'апрель') and (day > 30)) or\
#          ((month == 'май') and (day > 31)) or\
#          ((month == 'июнь') and (day > 30)) or\
#          ((month == 'июль') and (day > 31)) or\
#          ((month == 'август') and (day > 31)) or\
#          ((month == 'сентябрь') and (day > 30))or\
#          ((month == 'октябрь') and (day > 31)) or\
#          ((month == 'ноябрь') and (day > 30)) or\
#          ((month == 'декабрь') and (day > 31)) or day == 0:
#            print ('Перезапустите код и введите корректную дату')#проверка корректности сочетания дня и месяца


if ((month == 'февраль') and (day >= 20)) or ((month == 'март') and (day < 21)):
    print ('Рыбы') # рыбы 20 февраля — 20 марта
if ((month == 'март') and (day >= 21)) or ((month == 'апрель') and (day < 21)):
    print ('Овен') # овен 21 марта — 20 апреля  
if ((month == 'апрель') and (day >= 21)) or ((month == 'май') and (day < 22)):
    print ('Телец') # телец 21 апреля — 21 мая
if ((month == 'май') and (day >= 22)) or ((month == 'июнь') and (day < 22)):
    print ('Близнецы') # близнецы 22 мая — 21 июня
if ((month == 'июнь') and (day >= 22)) or ((month == 'июль') and (day < 23)):
    print ('Рак') # рак 22 июня — 22 июля
if ((month == 'июль') and (day >= 23)) or ((month == 'август') and (day < 22)):
    print ('Лев') # лев 23 июля — 21 августа
if ((month == 'август') and (day >= 22)) or ((month == 'сентябрь') and (day < 24)):
    print ('Дева') # дева 22 августа — 23 сентября  
if ((month == 'сентябрь') and (day >= 24)) or ((month == 'октябрь') and (day < 24)):
    print ('Весы') # весы 24 сентября — 23 октября
if ((month == 'октябрь') and (day >= 24)) or ((month == 'ноябрь') and (day < 23)):
    print ('Скорпион') # скорпион 24 октября — 22 ноября
if ((month == 'ноябрь') and (day >= 23)) or ((month == 'декабрь') and (day < 23)):
    print ('Стрелец') # стрелец 23 ноября — 22 декабря
if ((month == 'декабрь') and (day >= 23)) or ((month == 'январь') and (day < 21)):
    print ('Козерог') # козерог 23 декабря — 20 января
if ((month == 'январь') and (day >= 21)) or ((month == 'февраль') and (day < 20)):
    print ('Водолей') # водолей 21 января — 19 февраля
# Out:
# Введите месяц: октябрь
# Введите число: 24
# Скорпион

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
salary = float (input('Введите заработную плату в месяц: '))
ipot_persent = float (input ('Введите сколько процентов уходит на ипотеку: '))
live_percent = float (input ('Введите сколько процентов уходит на жизнь: '))
bonus = float (input ('Введите количество премий за год: '))


year_premia = salary * bonus #премия за год

holiday = year_premia / 2 #отпуск

save = year_premia / 2 #накопления

year_salary = salary * 12 #зарплата за год

year_ipot = salary * ipot_persent * 12 / 100 #ипотека за год

year_live = salary * live_percent * 12 / 100 #на жизнь за год

pens = year_salary - year_ipot - year_live #пенсия

print ('На ипотеку было потрачено: ', year_ipot)
print ('Было накоплено: ', save)
# Out:
# Введите заработную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# На ипотеку было потрачено:  360000.0
# Было накоплено:  100000.0
